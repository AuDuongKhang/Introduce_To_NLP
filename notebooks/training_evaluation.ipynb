# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir = "/content/drive/MyDrive/Colab Notebooks/NLP"
# %cd $dir
# Out:
# /content/drive/.shortcut-targets-by-id/1lRGqvKw_4b_rN03VqZLfIa7mUgbZUz1q/NLP

# %%
# !pip install transformers datasets torch evaluate sacrebleu nltk rouge_score bert_score meteor fastchrf
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Collecting meteor
#   Downloading meteor-2.0.17-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Collecting bgzip<0.6.0,>=0.5.0 (from meteor)
#   Downloading bgzip-0.5.0.tar.gz (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting biom-format<3.0.0,>=2.1.15 (from meteor)
#   Downloading biom-format-2.1.16.tar.gz (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 106.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cogent3<2025.0.0,>=2024.2.5a1 (from meteor)
#   Downloading cogent3-2024.12.19a1-py3-none-any.whl.metadata (14 kB)
# Collecting ete3<4.0.0,>=3.1.3 (from meteor)
#   Downloading ete3-3.1.3.tar.gz (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 103.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting packaging>=20.0 (from transformers)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pysam<0.23.0,>=0.22.0 (from meteor)
#   Downloading pysam-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from biom-format<3.0.0,>=2.1.15->meteor) (1.13.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from biom-format<3.0.0,>=2.1.15->meteor) (3.12.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from cogent3<2025.0.0,>=2024.2.5a1->meteor) (5.2.0)
# Collecting loky (from cogent3<2025.0.0,>=2024.2.5a1->meteor)
#   Downloading loky-3.4.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numba>0.54 in /usr/local/lib/python3.10/dist-packages (from cogent3<2025.0.0,>=2024.2.5a1->meteor) (0.60.0)
# Collecting scitrack (from cogent3<2025.0.0,>=2024.2.5a1->meteor)
#   Downloading scitrack-2024.10.8-py3-none-any.whl.metadata (8.9 kB)
# Collecting stevedore (from cogent3<2025.0.0,>=2024.2.5a1->meteor)
#   Downloading stevedore-5.4.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>0.54->cogent3<2025.0.0,>=2024.2.5a1->meteor) (0.43.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from loky->cogent3<2025.0.0,>=2024.2.5a1->meteor) (3.1.0)
# Collecting pbr>=2.0.0 (from stevedore->cogent3<2025.0.0,>=2024.2.5a1->meteor)
#   Downloading pbr-6.1.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 32.9 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.4 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 10.8 MB/s eta 0:00:00
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.1 MB/s eta 0:00:00
# Downloading meteor-2.0.17-py3-none-any.whl (61.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 MB 10.5 MB/s eta 0:00:00
# Downloading cogent3-2024.12.19a1-py3-none-any.whl (771 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.9/771.9 kB 47.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.8 MB/s eta 0:00:00
# Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 29.4 MB/s eta 0:00:00
# Downloading pysam-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (22.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 85.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.8 MB/s eta 0:00:00
# Downloading loky-3.4.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 5.4 MB/s eta 0:00:00
# Downloading scitrack-2024.10.8-py3-none-any.whl (7.8 kB)
# Downloading stevedore-5.4.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.2 MB/s eta 0:00:00
# Downloading pbr-6.1.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 10.6 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score, bgzip, biom-format, ete3
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=beb0fc6f7f27bc418f466e9fef02963cae97d28e41787649b831d73fd1acc64c
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for bgzip (setup.py) ... done
#   Created wheel for bgzip: filename=bgzip-0.5.0-cp310-cp310-linux_x86_64.whl size=237138 sha256=4c9eddbc687620ed23823b68b6ffdba25c4b9c74145c007593317a8c10cf0dba
#   Stored in directory: /root/.cache/pip/wheels/1c/b8/56/9367ade000d28a1a7f9439b7c040719e0d2c0152ddf216f5da
#   Building wheel for biom-format (pyproject.toml) ... done
#   Created wheel for biom-format: filename=biom_format-2.1.16-cp310-cp310-linux_x86_64.whl size=12158959 sha256=2213fb02529c348a1e2ca15cbfb46a1a330fcd7e29f378894809cc2906ab8366
#   Stored in directory: /root/.cache/pip/wheels/8e/a9/f9/197fd5a0e5bbab5f2e03c89194f6c194bed7af5d7a8c8759f3
#   Building wheel for ete3 (setup.py) ... done
#   Created wheel for ete3: filename=ete3-3.1.3-py3-none-any.whl size=2273787 sha256=2f3f58a7eccc3290f32db70885aa9d97d317e0aef8812c71815a24f2e36cda37
#   Stored in directory: /root/.cache/pip/wheels/a0/72/00/1982bd848e52b03079dbf800900120bc1c20e92e9a1216e525
# Successfully built rouge_score bgzip biom-format ete3
# Installing collected packages: ete3, bgzip, xxhash, scitrack, pysam, pyarrow, portalocker, pbr, packaging, loky, fsspec, dill, colorama, stevedore, sacrebleu, rouge_score, multiprocess, cogent3, biom-format, meteor, datasets, bert_score, evaluate
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed bert_score-0.3.13 bgzip-0.5.0 biom-format-2.1.16 cogent3-2024.12.19a1 colorama-0.4.6 datasets-3.2.0 dill-0.3.8 ete3-3.1.3 evaluate-0.4.3 fsspec-2024.9.0 loky-3.4.1 meteor-2.0.17 multiprocess-0.70.16 packaging-23.2 pbr-6.1.0 portalocker-3.0.0 pyarrow-15.0.2 pysam-0.22.1 rouge_score-0.1.2 sacrebleu-2.4.3 scitrack-2024.10.8 stevedore-5.4.0 xxhash-3.5.0

# %%
import torch

if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# GPU is available

# %%
# !python main.py
# Out:
# 2024-12-31 05:07:50.084066: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-31 05:07:50.116775: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-31 05:07:50.126496: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-31 05:07:50.152089: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-31 05:07:51.729978: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 22637/22637 [00:06<00:00, 3464.68 examples/s]
# Batch 1/2830 processed
# Batch 2/2830 processed
# Batch 3/2830 processed
# Batch 4/2830 processed
# Batch 5/2830 processed
# Batch 6/2830 processed
# Batch 7/2830 processed
# Batch 8/2830 processed
# Batch 9/2830 processed
# Batch 10/2830 processed
# Batch 11/2830 processed
# Batch 12/2830 processed
# Batch 13/2830 processed
# Batch 14/2830 processed
# Batch 15/2830 processed
# Batch 16/2830 processed
# Batch 17/2830 processed
# Batch 18/2830 processed
# Batch 19/2830 processed
# Batch 20/2830 processed
# Batch 21/2830 processed
# Batch 22/2830 processed
# Batch 23/2830 processed
# Batch 24/2830 processed
# Batch 25/2830 processed
# Batch 26/2830 processed
# Batch 27/2830 processed
# Batch 28/2830 processed
# Batch 29/2830 processed
# Batch 30/2830 processed
# Batch 31/2830 processed
# Batch 32/2830 processed
# Batch 33/2830 processed
# Batch 34/2830 processed
# Batch 35/2830 processed
# Batch 36/2830 processed
# Batch 37/2830 processed
# Batch 38/2830 processed
# Batch 39/2830 processed
# Batch 40/2830 processed
# Batch 41/2830 processed
# Batch 42/2830 processed
# Batch 43/2830 processed
# Batch 44/2830 processed
# Batch 45/2830 processed
# Batch 46/2830 processed
# Batch 47/2830 processed
# Batch 48/2830 processed
# Batch 49/2830 processed
# Batch 50/2830 processed
# Batch 51/2830 processed
# Batch 52/2830 processed
# Batch 53/2830 processed
# Batch 54/2830 processed
# Batch 55/2830 processed
# Batch 56/2830 processed
# Batch 57/2830 processed
# Batch 58/2830 processed
# Batch 59/2830 processed
# Batch 60/2830 processed
# Batch 61/2830 processed
# Batch 62/2830 processed
# Batch 63/2830 processed
# Batch 64/2830 processed
# Batch 65/2830 processed
# Batch 66/2830 processed
# Batch 67/2830 processed
# Batch 68/2830 processed
# Batch 69/2830 processed
# Batch 70/2830 processed
# Batch 71/2830 processed
# Batch 72/2830 processed
# Batch 73/2830 processed
# Batch 74/2830 processed
# Batch 75/2830 processed
# Batch 76/2830 processed
# Batch 77/2830 processed
# Batch 78/2830 processed
# Batch 79/2830 processed
# Batch 80/2830 processed
# Batch 81/2830 processed
# Batch 82/2830 processed
# Batch 83/2830 processed
# Batch 84/2830 processed
# Batch 85/2830 processed
# Batch 86/2830 processed
# Batch 87/2830 processed
# Batch 88/2830 processed
# Batch 89/2830 processed
# Batch 90/2830 processed
# Batch 91/2830 processed
# Batch 92/2830 processed
# Batch 93/2830 processed
# Batch 94/2830 processed
# Batch 95/2830 processed
# Batch 96/2830 processed
# Batch 97/2830 processed
# Batch 98/2830 processed
# Batch 99/2830 processed
# Batch 100/2830 processed
# Batch 101/2830 processed
# Batch 102/2830 processed
# Batch 103/2830 processed
# Batch 104/2830 processed
# Batch 105/2830 processed
# Batch 106/2830 processed
# Batch 107/2830 processed
# Batch 108/2830 processed
# Batch 109/2830 processed
# Batch 110/2830 processed
# Batch 111/2830 processed
# Batch 112/2830 processed
# Batch 113/2830 processed
# Batch 114/2830 processed
# Batch 115/2830 processed
# Batch 116/2830 processed
# Batch 117/2830 processed
# Batch 118/2830 processed
# Batch 119/2830 processed
# Batch 120/2830 processed
# Batch 121/2830 processed
# Batch 122/2830 processed
# Batch 123/2830 processed
# Batch 124/2830 processed
# Batch 125/2830 processed
# Batch 126/2830 processed
# Batch 127/2830 processed
# Batch 128/2830 processed
# Batch 129/2830 processed
# Batch 130/2830 processed
# Batch 131/2830 processed
# Batch 132/2830 processed
# Batch 133/2830 processed
# Batch 134/2830 processed
# Batch 135/2830 processed
# Batch 136/2830 processed
# Batch 137/2830 processed
# Batch 138/2830 processed
# Batch 139/2830 processed
# Batch 140/2830 processed
# Batch 141/2830 processed
# Batch 142/2830 processed
# Batch 143/2830 processed
# Batch 144/2830 processed
# Batch 145/2830 processed
# Batch 146/2830 processed
# Batch 147/2830 processed
# Batch 148/2830 processed
# Batch 149/2830 processed
# Batch 150/2830 processed
# Batch 151/2830 processed
# Batch 152/2830 processed
# Batch 153/2830 processed
# Batch 154/2830 processed
# Batch 155/2830 processed
# Batch 156/2830 processed
# Batch 157/2830 processed
# Batch 158/2830 processed
# Batch 159/2830 processed
# Batch 160/2830 processed
# Batch 161/2830 processed
# Batch 162/2830 processed
# Batch 163/2830 processed
# Batch 164/2830 processed
# Batch 165/2830 processed
# Batch 166/2830 processed
# Batch 167/2830 processed

# %%
# rouge
# !python main.py
# Out:
# 2024-12-31 07:41:07.049075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-31 07:41:07.084740: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-31 07:41:07.095051: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-31 07:41:07.120344: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-31 07:41:08.377401: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 22637/22637 [00:07<00:00, 2891.87 examples/s]
# Batch 1/2830 processed
# Batch 2/2830 processed

# %%
# meteor
# !python main.py
# Out:
# 2024-12-31 07:47:04.339701: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-31 07:47:04.362270: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-31 07:47:04.368156: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-31 07:47:04.382942: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-31 07:47:05.664846: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 22637/22637 [00:08<00:00, 2813.62 examples/s]
# Downloading builder script: 100% 7.02k/7.02k [00:00<00:00, 20.9MB/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Batch 1/2830 processed
# Batch 2/2830 processed
# Batch 3/2830 processed
# Batch 4/2830 processed
# Batch 5/2830 processed
# Batch 6/2830 processed
# Batch 7/2830 processed
# Batch 8/2830 processed
# Batch 9/2830 processed

# %%
# bleu
# !python main.py

# %%
# ter
# !python main.py

# %%
# chrf
# !python main.py
